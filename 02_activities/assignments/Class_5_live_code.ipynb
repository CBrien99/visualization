# %% [markdown]
# # Making Vis with seaborn

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
tips = sns.load_dataset("tips")
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.lmplot(data=tips,       # choose our dataset
           x="total_bill",  # define our x variable
           y="tip")         # define our y variable

# %%
sns.set_style('whitegrid')

# %%
tipgraph = sns.lmplot(data=tips,
                      x='total_bill',
                      y='tip')

tipgraph.set(title='Tips vs. Total Bill',
             xlabel='Total Bill ($)',
             ylabel='Tip Amount ($)')

# %%
fig = plt.subplots(figsize=(10, 3))

# %%
tipgraph = sns.lineplot(data=tips,
                        x='total_bill',
                        y='tip',
                        color='hotpink',
                        linestyle='--',
                        linewidth=3,
                        marker='o',
                        markerfacecolor='indigo')

# %%
tipgraph = sns.scatterplot(data=tips, x='total_bill',
                           y='tip', style='time', hue='day', palette=['purple',
                                                                      'hotpink','deepskyblue',
                                                                      'yellowgreen'])

tipgraph.set(title='Tips vs. Total Bill',
             xlabel='Total Bill ($)',
             ylabel='Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
sns.pairplot(
    data = tips,
    hue = 'day')

# %%
daysplot = sns.relplot(
    data=tips,
    x="total_bill",
    y="tip",
    hue="sex",
    col="day",
    kind="scatter",
    col_wrap=2)

# %%
# !!pip install plotly
# Out:
# ['Requirement already satisfied: plotly in c:\\users\\chels\\appdata\\local\\programs\\python\\python312\\lib\\site-packages (6.0.1)',
#  'Requirement already satisfied: narwhals>=1.15.1 in c:\\users\\chels\\appdata\\local\\programs\\python\\python312\\lib\\site-packages (from plotly) (1.38.2)',
#  'Requirement already satisfied: packaging in c:\\users\\chels\\appdata\\roaming\\python\\python312\\site-packages (from plotly) (24.2)']

# %%
import plotly.graph_objects as go    # 'go' is "graph objects"

x = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])

import plotly.io as pio
pio.renderers.default = 'browser'

# %%
graph = go.Figure()

# Next, choose our plot type (bar) and our data
graph.add_trace(go.Bar(x=x, y=y1))
graph.update_layout(
    title="Pirate Scores",
    xaxis_title="Pirates",
    yaxis_title="Score")

# Finally, show our plot!
graph.show()

# %%
graph = go.Figure()
graph.add_trace(go.Scatter(x=x1, y=y1, mode='markers',    # we want points for a scatter plot
              marker=dict(
                  size=15,            # point size
                  color='hotpink',    # point color
                  opacity=0.6,        # point transparency/alpha
                  line=dict(width=4, color='purple')  # point outline
              )))

graph.update_layout(
    title='Interactive Pirate Plot',
    xaxis_title='Pirates',
    yaxis_title='Scores',
    width=500, height=500)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 graph = go.Figure()
# ----> 2 graph.add_trace(go.Scatter(x=x1, y=y1, mode='markers',    # we want points for a scatter plot
#       3               marker=dict(
#       4                   size=15,            # point size
#       5                   color='hotpink',    # point color
#       6                   opacity=0.6,        # point transparency/alpha
#       7                   line=dict(width=4, color='purple')  # point outline
#       8               )))
#      10 graph.update_layout(
#      11     title='Interactive Pirate Plot',
#      12     xaxis_title='Pirates',
#      13     yaxis_title='Scores',
#      14     width=500, height=500)
#
# NameError: name 'x1' is not defined

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud
df = pd.read_csv("https://raw.githubusercontent.com/ageron/data/main/movie_reviews/movie_quotes.csv")
df = df.dropna(subset=["quote"])
df
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 from wordcloud import WordCloud
# ----> 2 df = pd.read_csv("https://raw.githubusercontent.com/ageron/data/main/movie_reviews/movie_quotes.csv")
#       3 df = df.dropna(subset=["quote"])
#       4 df
#
# ...

# %%
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted

# Then define our sets
A = set(["apple", "banana", "watermelon"])
B = set(["pumpkin", "blueberry", "apple", "key lime"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 from matplotlib_venn import venn2, venn2_circles, venn2_unweighted
#       3 # Then define our sets
#       4 A = set(["apple", "banana", "watermelon"])
#
# ModuleNotFoundError: No module named 'matplotlib_venn'

# %%
diagram = venn2_unweighted([A, B],
                           set_labels = ("Fruits", "Pies"),
                           set_colors=("blue", "red"),
                           alpha=0.5)

diagram.get_label_by_id('10') \
       .set_text("\n".join(A - B))

diagram.get_label_by_id('11') \
       .set_text("\n".join(A & B))

diagram.get_label_by_id('01') \
       .set_text("\n".join(B - A))


plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 diagram = venn2_unweighted([A, B],
#       2                            set_labels = ("Fruits", "Pies"),
#       3                            set_colors=("blue", "red"),
#       4                            alpha=0.5)
#       6 diagram.get_label_by_id('10') \
#       7        .set_text("\n".join(A - B))
#       9 diagram.get_label_by_id('11') \
#      10        .set_text("\n".join(A & B))
#
# NameError: name 'venn2_unweighted' is not defined
